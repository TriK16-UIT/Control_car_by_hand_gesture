# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import KNeighborsClassifier as knn
from sklearn.linear_model import LogisticRegression as lr 
from sklearn.naive_bayes import GaussianNB as nb
import sklearn.metrics as sm
from sklearn.metrics import confusion_matrix

# %%
keypoint = pd.read_csv('Models\KeyPoint\keypoint.csv')
keypoint.columns = [i for i in range(keypoint.shape[1])]
keypoint = keypoint.rename(columns= {0: 'Hand Sign'})
keypoint
# Out:
#      Hand Sign         1         2             3         4         5  \
# 0            0  0.177878  0.799041  6.450000e-07  0.287185  0.775292
# 1            0  0.177631  0.768650  5.400000e-07  0.278664  0.745434
# 2            0  0.171568  0.749729  5.390000e-07  0.269602  0.730948
# 3            0  0.167381  0.737172  6.270000e-07  0.262879  0.721749
# 4            0  0.162066  0.737017  6.430000e-07  0.260693  0.726708
# ..         ...       ...       ...           ...       ...       ...
# 326          1  0.223818  0.512586 -3.300000e-07  0.284300  0.504662
# 327          1  0.221369  0.493583 -1.220000e-07  0.282533  0.481668
# 328          1  0.219433  0.475747 -1.770000e-07  0.284240  0.469408
# 329          1  0.221657  0.477798  1.870000e-07  0.282102  0.470444
# 330          1  0.220902  0.501943 -2.510000e-07  0.285849  0.488889
#
#             6         7         8         9  ...       117       118  \
# ...

# %%
x = keypoint.iloc[:, 1:127]
y = keypoint['Hand Sign']

# %%
feature_train, feature_test, label_train, label_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
feature_train
# Out:
#           1         2             3         4         5         6         7    \
# 259  0.149903  0.801745 -1.390000e-07  0.221927  0.813036 -0.073588  0.280382
# 140  0.101873  0.659808  7.580000e-07  0.208339  0.634208 -0.050086  0.295705
# 296  0.188965  0.454040  1.690000e-07  0.254443  0.439739 -0.063212  0.315759
# 1    0.177631  0.768650  5.400000e-07  0.278664  0.745434 -0.041490  0.359265
# 239  0.257658  0.548725 -3.290000e-07  0.320276  0.549688 -0.060755  0.384528
# ..        ...       ...           ...       ...       ...       ...       ...
# 323  0.240571  0.638221  1.180000e-08  0.300749  0.633001 -0.042629  0.369780
# 192  0.306227  0.506209 -1.780000e-07  0.365511  0.494713 -0.073830  0.430789
# 117  0.187372  0.817603  6.170000e-07  0.290193  0.795980 -0.039913  0.371862
# 47   0.157423  0.921124  5.610000e-07  0.267272  0.897545 -0.028702  0.348198
# 172  0.167048  0.817271  5.490000e-07  0.271816  0.799256 -0.042442  0.354162
#
# ...

# %%
label_train
# Out:
# 259    1
# 140    0
# 296    1
# 1      0
# 239    1
#       ..
# 323    1
# 192    1
# 117    0
# 47     0
# 172    0
# Name: Hand Sign, Length: 264, dtype: int64

# %%
feature_test
# Out:
#           1         2             3         4         5         6         7    \
# 60   0.315677  0.704635  4.610000e-07  0.413993  0.687403 -0.030761  0.492111
# 74   0.148571  0.735790  6.980000e-07  0.250140  0.717507 -0.043122  0.334121
# 132  0.111085  0.685887  8.190000e-07  0.219813  0.673695 -0.057634  0.301102
# 63   0.324621  0.768392  3.980000e-07  0.419790  0.752120 -0.029977  0.496312
# 55   0.181457  0.700035  6.680000e-07  0.279655  0.683090 -0.045498  0.360726
# ..        ...       ...           ...       ...       ...       ...       ...
# 286  0.184906  0.578832  1.180000e-07  0.242820  0.578514 -0.073969  0.310020
# 171  0.160378  0.799636  5.560000e-07  0.266114  0.784709 -0.043899  0.349176
# 294  0.182452  0.489913  2.060000e-07  0.241880  0.482449 -0.077421  0.311438
# 249  0.214369  0.713044 -2.240000e-07  0.278038  0.722695 -0.066149  0.338308
# 238  0.251668  0.521239 -3.410000e-07  0.310523  0.521269 -0.055137  0.379149
#
# ...

# %%
label_test
# Out:
# 60     0
# 74     0
# 132    0
# 63     0
# 55     0
#       ..
# 286    1
# 171    0
# 294    1
# 249    1
# 238    1
# Name: Hand Sign, Length: 67, dtype: int64

# %%
svm = SVC(C=10, gamma=0.1, kernel='rbf')
svm.fit(feature_train, label_train)
# Out:
# SVC(C=10, gamma=0.1)

# %%
def calc_accuracy(method, label_test, pred):
  print("accuracy score for ", method, sm.accuracy_score(label_test,pred))
  print("precision_score for ", method, sm.precision_score(label_test,pred,average='micro'))
  print("f1 score for ", method, sm.f1_score(label_test,pred,average='micro'))
  print("recall score for ", method, sm.recall_score(label_test,pred,average='micro'))
  accuracy = sm.accuracy_score(label_test,pred)
  return accuracy

# %%
pred = svm.predict(feature_test)
svm_accuracy = calc_accuracy("SVM", label_test, pred)
svm_accuracy
# Out:
# accuracy score for  SVM 1.0
# precision_score for  SVM 1.0
# f1 score for  SVM 1.0
# recall score for  SVM 1.0
# 1.0

# %%
logr = lr()
logr.fit(feature_train, label_train)
# Out:
# LogisticRegression()

# %%
pred = logr.predict(feature_test)
logr_accuracy = calc_accuracy("Logistic Regression", label_test, pred)
# Out:
# accuracy score for  Logistic Regression 1.0
# precision_score for  Logistic Regression 1.0
# f1 score for  Logistic Regression 1.0
# recall score for  Logistic Regression 1.0

# %%
gnb = nb()
gnb.fit(feature_train, label_train)
# Out:
# GaussianNB()

# %%
pred = gnb.predict(feature_test)
nb_accuracy = calc_accuracy("Naive Bayes", label_test, pred)
# Out:
# accuracy score for  Naive Bayes 1.0
# precision_score for  Naive Bayes 1.0
# f1 score for  Naive Bayes 1.0
# recall score for  Naive Bayes 1.0

# %%
import pickle
with open('model', 'wb') as f:
    pickle.dump(svm, f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Admin\Desktop\HDL\Hand gesture\Final-Project\train.ipynb Cell 16 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/HDL/Hand%20gesture/Final-Project/train.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> import pickle
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/HDL/Hand%20gesture/Final-Project/train.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> model_path = 'Final-Project/Models/KeyPoint/model.pkl'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/HDL/Hand%20gesture/Final-Project/train.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> with open(model_path, 'wb') as f:
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/HDL/Hand%20gesture/Final-Project/train.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a>     pickle.dump(svm, f)
#
# ...
